-- %% [markdown]
-- # README
--
-- Hello, and welcome to the **BCME10 Notebook**&trade;. This Notebook is based on iHaskell Notebook. It provides an interface similar to an interactive shell along the lines of GHCi, the stand alone Haskell interactive development environment (IDE). However, it is much more powerful than GHCi, and provides features such as syntax highlighting, autocompletion, multi-line input cells, integrated documentation, rich output visualization, and more.
--
-- iHaskell is implemented as a language kernel for the [Jupyter](https://jupyter.org) project, which means that although the entire thing is written only in Haskell, we get a beautiful notebook interface practically for free.
--
-- The notebook can also be run entirely within a modern browser, such as Firefox, using MicroHS. Visiting [HubTizard] {https://hubtizard.github.io/xeus-haskell/} will download JupyterLite, a browser hosted Jupyter server, together with thes MicroHS Haskell IDE and a set of notebooks including this one located at ./notebooks/BCME in the JupyterLite file browser.
--
-- Vistors are welcome to browse the other notebooks, and enrol in the Haskell Road to Mathematics Future Learn course to learn more. Email sociality@me.com for more information.

-- %% [markdown]
-- # Acknowledgements
--
-- Caleb Gattegno, a mathematician and educationalist, who studied the subordination of teaching to learning, drew attention to the central importance of model making for the learner to become self-aware. Awareness is key to learning. Indeed Gattegno's rubric was `only awareness is educable.`
--
-- We will follow John Mason and Brendan Fong and colleagues' advice on how teachers learn and how to encourage awareness by developing situations that require mathematical modelling in Haskell.
--
-- Mason suggests that
-- > the critical feature for promoting algebraic thinking is not the tasks given to learners, but rather the opportunities noticed by teachers for calling upon learners’ powers to express and manipulate generalities, and that this is enriched when teachers engage in similar tasks at their own level, so as to sensitise themselves to pedagogic opportunities when working with learners. (How Early Is Too Early for Thinking Algebraically?, 2018)
--
-- Fong and colleagues wrote about learning to program:
-- > We'll be using things from day one, without fully understanding their meaning, thus constantly incurring a conceptual debt. Some of this debt will be paid later. Some of it will stay with us forever. The alternative would be to first learn about cartesian closed categories and domain theory, formally define simply typed lambda calculus, build its categorical model, and only then wave our hands a bit and claim that at its core Haskell approximates this model (Programming with Categories, DRAFT)
--
-- Learning school mathematics with Haskell is an opportunity for teachers to appreciate how learners approach novel (to them) mathematising situations.
--
-- We do this by modelling in Haskell how learners can apply their inherent mental powers, such as transitive inference, to mathematical modelling.
--
-- Caleb Gattegno wrote
-- >  The value of a model is to be found in its capacity to make us think on the subject, to allow us to shed some light upon hidden matters connected to the field for which the model is proposed... Of course, there are many many things I do automatically and I do not need to be aware of, although in a number of cases I could become aware of them. So long as I am not aware, I cannot say whether I use a model or not. But as soon as I become aware, I can. (A working model for health, 1986)

-- %% [markdown]
-- # Chapter 1 Working with types and functions
--
-- In Haskell, understanding types is fundamental. This notebook demonstrates several methods for working with types, especially useful when the `:type` command might not be available in all environments.
--
-- We start by considering built-in types: these are sets of values with additional characteristics (J.H. Morris, Types are not Sets, 1973). Like many other languages Haskell has primitive types: whole numbers, in mathematics *integers*, in Haskell `Int` as well as `Char` or `Bool` (which takes two values `True`,`False`).
--
-- Additional types can be created using a type synonym such as `type String = [Char]`.This defines a `String` as a list of `Char` eg "abc":: String is the same thing as ['a','b','c'] :: String. The keywords `newtype` and `data` are used to declare type constructors.
--
-- The notebook contains Markdown cells, which we have seen thus far, and Code cells such as the one that follows. Readers are encouraged to run the code fragments by pressing the Run widget (Left pointing solid triangle in xeus). They should pause and ask themselves what they expect to see before they run the code.
--
-- Types are so important that we have several methods of interrogating the type of a value or function.

-- %%
:type (==) -- == is a built in predicate, a function that compares two arguments and returns a Bool

"abc"  ==  ['a','b','c']

-- %% [markdown]
-- ## Method 1: Using :type (if available)
--
-- The `:type` or `:t` command can interrogate values and functions. Try it below - if it works, great! If not, use the alternative methods that follow.

-- %%
a = 1
a -- will return the value of a
-- :type a  -- Try this command by editing this comment out (remove the --)

-- %% [markdown]
-- ## Method 2: Explicit Type Annotations
--
-- You can always specify types explicitly using the :: syntax. This both documents your code and helps catch type errors.

-- %%
-- Annotate values explicitly
penCount = 3 :: Int
message = "Hello" :: String

-- Show the values
penCount

-- %% [markdown]
-- ## Method 3: Using Type Errors for Discovery
--
-- Deliberately causing type errors reveals what types Haskell expects. The error messages tell you the types!

-- %%
-- These examples would cause type errors (when commented out):
-- "hello" + 5        -- Error reveals: String vs Num
-- [1,2,3] ++ 5       -- Error reveals: List vs Int
-- True + False       -- Error reveals: Bool vs Num

-- The error messages show expected and actual types!

-- %% [markdown]
-- ## Method 4: Test with Known Types¶
--
-- If a function works with certain values, you can infer its type.

-- %%
-- If this works with integers:
testFunc = (2+)
testFunc 5    -- Works, so probably Int -> Int

-- If we tried: testFunc "hi" it would fail, confirming it's not for strings

-- %% [markdown]
-- ## Understanding the Type of `plus`

-- %%
-- define plus
plus = (+)

-- %% [markdown]
-- The type of `plus` is: `forall {a}. Num a => a -> a -> a`
--
-- This is read as: for every type `a` in type class `Num`, plus is a function that takes two arguments of type `a` and returns a result of the same type.
--
-- **Breaking it down:**
-- - `forall {a}` - works for any type `a`
-- - `Num a =>` - as long as `a` is a numeric type
-- - `a -> a -> a` - takes two `a`s and returns an `a`
--
-- This means `plus` works with `Int`, `Double`, any built-in numeric type or any type instantiating (deriving) the `Num` type class

-- %% [markdown]
-- ## Demonstrating Polymorphism
--
-- Since `plus` is polymorphic, it works with any of these numeric types:

-- %%
-- comment out one statement at a time
-- Works with Int
plus (2 :: Int) (3 :: Int)

-- Works with Double
-- plus (2.5 :: Double) (3.7 :: Double)

-- %% [markdown]
-- ## Lambda expressions (anonymous functions)
--
-- Lambda expressions are a mechanism for declaring a function without giving it a names. They have the same type signature as their equivalent named functions. Since we already defined plus above, we know the lambda version has the same polymorphic type.

-- %%
plusAnon = \ x y -> x + y -- plus can also be defined with an anonymous, lambda, expression

-- Test the lambda version
plusAnon 5 7

-- check its type.

-- %% [markdown]
-- ## Summary: Methods for Working with Types
--
-- We've demonstrated four methods for understanding types in Haskell:
--
-- 1. **`:type` command** - Use if available
-- 2. **Explicit annotations** - Always works: `value :: Type`
-- 3. **Type errors** - Reveal expected types through error messages
-- 4. **Testing** - Infer types by seeing what works
--
-- These methods are especially useful when working in environments like the xeus-haskell MicroHS console where `:type` may not be available.

-- %% [markdown]
-- # Chapter 2. Modelling Named Numbers
--
-- In this chapter we will consider how types defined with type synonyms and `newtype` can be used to model simple situations such as those found in arithemetic word problems.
--
-- In chapter 2 we develop an extended example of the use of `data` to model a number system imagined through the affordances of the set of Cuisenaire rods.

-- %% [markdown]
-- ## A Named Number Model
--
-- For example consider `named numbers` such a *n apples* or *m kilometres*. Computation with named numbers is found from the outset of mathematics curriculum in Key Stage 1. They are the foundation for the word problems of early arithmetic.
--
-- We model named numbers as types in the type class `Num`. In mathematics a type is a subset of a universe of values: in informatics behavioural type checking prevents operations such as + being applied to values that are not valid representations of the intended objects.
--
-- In this section we model the addition of apples and bananas, and the division of eggs and butter.
--
-- A typical Key Stage 1 national assessment question give the weight of a strawberry and its weight combined with an apple, a pear, orange and kiwi in turn and asks what are the weights of the individual fruits? (KS1 Maths Reasoning Paper, 2018).
--
-- We apply what we have learnt to developing an algorithm to solve this problem.
--
-- ### newtype (homogeneous arithmetic)

-- %%
newtype Apple = Apple Int deriving (Show, Num) 
-- here the first Apple is a type constructor. 
-- it introduces Apple as the name of a type. 
-- It lives in the type namespace, and you'd use it in function type signatures such as weight :: Apple -> Int.
-- The second Apple is a 'data constructor'. This is a function that builds values of the type Apple 
-- from the built-in type Int. It lives in the term/value namespace
-- deriving Show prints a Haskell value as a human readable String
-- deriving Num means that Apple is an instance of Num which contains amongst other methods the operator +

-- %%
(1 :: Apple) + (2 :: Apple)

-- %%
plus (1 :: Apple)(2 :: Apple)

-- %%
:type (+) -- plus is a function that takes two arguments of a type instantiating (deriving) type class Num 
-- and returns a value of that type 

:info Apple -- check Apple instantiates Num

:type (Apple 1 +) -- what is the type signature of the partially applied curried function and section (Apple 1 +)?
-- A curried function is a function that, instead of taking multiple arguments all at once, 
--  takes them one at a time, with each application returning a new function that expects the next argument 
-- until finally, after the last argument, you get the actual result.
-- (Apple 1 +) is called a left section as it specifies partially applying (+) to Apple 1 as its first argument.
-- the syntax (+) indicates that the usually binary function +, as in 1+2, is to be applied as a prefix (+) 1 2

-- %%
(Apple 1 +) 2

-- %% [markdown]
-- ### newtype (heterogeneous arithmetic)

-- %%
-- Now try adding Apples and Bananas
newtype Banana = Banana Int deriving (Show, Num) -- model the number of Bananas as a newtype

-- %%
(1 :: Apple) + (2 :: Banana) -- attempt to add Apples and Bananas

-- %% [markdown]
-- This gives a type matching error. To get a correct answer we will need two functions to extract the number of fruits for each fruit and add them.
--
-- This is an example of what John Baez calls class inclusion (Can Five-Year-Olds Compute Coproducts?, John Baez, 2009). In his article he shows that class inclusion is a dual operation to transitive inference (that is if `a` implies `b` and `b` implies `c` then `a` implies `c`). He argues that "Children perform certain tasks (such as transitive inference) that are best explained by cognitive scientists as evidence for the possession of category theoretic structures in their minds." We will see how to model this when we meet the `data` keyword.

-- %% [markdown]
-- ### KS1 word problem model and solution
--
-- We advocate the `questions procedure` for solving arithmetic word problems (Economy of Thought: A Neglected Principle of Mathematics Education, Alexandre V. Borovik, 2017). Given a problem, such as the KS1 word problem above the student is taught to ask: what is the data? what is its structure? what are its properties?
--
-- In this case the answers can be calculated from the given weight of the strawberry (24g) and a table structure of objects and combined weights.
-- | | +apple | +pear | +orange | +kiwi |
-- |---|---|---|---|---|
-- | Combined weight | 69g | 82g | 98g | 74g |
--
-- By repeated subtraction of 24g we obtain the answers
--
-- | | apple | pear | orange | kiwi |
-- |---|---|---|---|---|
-- | Individual weight | 45g | 58g | 74g | 50g |

-- %%
-- in Haskell we can use the (subtract 24) section to model of the computation  
-- for a single pair of fruits 
-- together with the map higher-order function which takes two arguments:
-- a function from a->b and a list of a's returning a list of b's
:type map

-- %%
-- we can model the data in the table list of combined weights
combinedWeights = [69,82,98,74]
-- the calculation of the individual weights follows by applying the section to this list
individualWeights = map (subtract 24) combinedWeights
individualWeights -- show the values

-- %% [markdown]
-- ### type synonym
--
-- Type synonyms are useful for modelling domains which have properties of built-in types.
--
-- D E Littlewood remarked in his The Skeleton Key to Mathematics (1949) that
-- >Apart from specialized mathematicians, few people realize that, for example, the number 2 can have some half a dozen distinct meanings. These differences of meaning are reflected in the logical definitions of numbers.
--
-- >Consider on the one hand two eggs, and on the other hand two pounds of butter. That these "two's" really mean something different becomes apparent if the fraction "one half" is substituted for "two". It is just as easy to take half-a-pound of butter as it is to take two pounds, but to remove a half of an egg from a basket containing two would present a problem. Breaking the egg and dividing the contents is no solution, for  a broken egg is not the same as an egg. Again, it can be determined precisely by a process of counting that there are exactly two eggs in a basket. But the two concerning the pounds of butter has nothing to do with counting, unless by an unnecessary complication the butter is already weighed up in pounds, and the two in any case is only an approximation.
--
-- #### The case of half an egg

-- %%
-- we can build a model of the egg domain using the built-in type Int (if we ignore negative eggs)
type Egg = Int

-- %%
b = 1:: Egg  -- Take an egg

-- %%
(1/2*)b -- And try to halve it? why does this fail?

-- %%
:type (1/2*) -- what is the type signature of the function (1/2*)?

-- %% [markdown]
-- That is for all types `a` which are constrained to be members of type class `Fractional` (1/2*) the shape (arity) of its type signature is `a -> a`. The constraint `forall {a}. Fractional a =>` is not part of the arrow type.

-- %%
:info Int -- what type classes contain Int

-- %% [markdown]
-- `Int` is not in the Fractional type class. This prevents us from taking half of an even number of eggs.

-- %%
(1/2*)2::Egg

-- %% [markdown]
-- #### The butter model
--
-- Now consider the case of modeling Littlewood's butter domain. Here the objects are slabs of butter, the data is their weight and the relationship between objects is that one slab is related to its two halves by the halving operation.
--
-- We can choose a different built-in type for the Butter domain: Haskell has other number types such as `Float` and `Double` depending how many digits of precision are required. There is also a `Rational` type which represents a number as pair of `Int` with a syntax for showing the pair such as `3 % 5` for $\frac{3}{5}$.

-- %%
import Data.Ratio
type Butter = Rational
a = 2 :: Butter
(1/2*)a

-- %%
-- Rational arithmetic reduces a term to its lowest form
6 % 12 +  3 % 12

-- %% [markdown]
-- # Chapter 2: What We Owe Children
--
-- Caleb Gattegno wrote (What we Owe Children,1970, p23, Internet Archive) that
--
-- > We teach a child to learn to say, '2 apples plus 3 apples make 5 apples.' '2 pens plus 3 pens make 5 pens.' What has he proved to us in learning this? That he knows that 2,3 and 5 are three operators that go together, that 2 and 3 can be passed from apples to pens to pears to chairs and so forth. This is an important accomplishment. But teachers say children have to know that 2 plus 3 is 5. What do they mean? They mean that 2 apples and 3 apples is concrete, that 2 pens and 3 pens is also concrete and that such a concreteness does not give children a proper grasp of the abstract concept of 2 and 3 and 5 and the relationship 2 plus 3. But is this so?
--
-- Gattegno's pedagogy was built on a deep appreciation of what was then a branch of research mathematics, developed by Saunders Mac Lane and colleagues as Category Theory, and also known today as Conceptual Mathematics (Choquet, What is Modern Mathematics,1963; Cheng, How to Bake Pi, 2015).
--
-- His approach to introducing teachers and learners to the technical vocabulary of advanced mathematics was in the spirit of a pure mathematician. Fields Prize winner Michael Atiyah (How research is carried out, Bulletin IMA 10, 1974,pp232-4) described their approach in these terms:
--
-- > We must bear in mind that mathematics is a human activity, that the aim of solving problems or doing mathematics is presumably to pass on information you have gained for posterity. Now we have to remember that the human mind is finite and cannot really digest infinite numbers of problems one after the other and remember them all. The aim of theory really is, to a great extent, that of systematically organising past experience in such a way that the next generation, our students and their students and so on, will be able to absorb the essential aspects in as painless a way as possible, and this is the only way in which you can go on cumulatively building up any kind of scientific activity without eventually coming to a dead end.
--
-- It is in this spirit that we offer this reflection on Gattegno's words, in the form of a concept graph to unpick the ideas that he uses and relate them to one another and to the types and functions of modern treatments of conceptual mathematics. This is illustrated in this interactive notebook in Haskell, a functional programming language whose model of computation is to all intents and purposes conceptual mathematics.
--
-- The figure below shows how the idea of Number is introduced as a __whole number__ or __Integer__ in Year 1. A modern analysis of this concept will determine two aspects: its __data__ which we call the _value_ of the number, and its __structure__ which is sometimes called a _relationship_ between the values, or an _operator_ on these values. The figure, sometimes called a disciplinary concept graph (DCG), illustrates how these two aspects of number come together in Haskell with the idea of a curried function: that is a function that, instead of taking multiple arguments all at the same time, it takes them one by one, with each function application returning a new function that expects the succeeding argument until finally, after the last argument, you get an actual result.
--
-- For example, in Gattegno's Mathematics (volume 1) he works from the outset with code letter names for the rods and the operators + (plus) and $\times$ (of). He has not yet given the rods number labels to name rod constructions such as trains (`w+r`) yet he uses number names as _multipliers_  (`2w=r`) and number names in _unit fractions_ which appear as operators eg `half of` in $(\frac{1}{2} \times r = w)$.
--
-- <img src="images/Concept1Analysis23a.png" width="400"/>
--
-- To define this concept of a function the learner needs an awareness of the dynamic imagery implied by the pattern named `r+g=y` (say) -- that is a train of a red and green rod side by side with a yellow rod. Gattegno uses a metaphor to correlate the equivalence between the lengths of the two trains `r+g` and `y` with the movement of the eye from one end of the `y` rod  to the other end corresponding to the two successive movements from one end of the adjacent `r` to the start and end of its neighbour `g`.
--
-- We can call these two movements `(+y)` and `(+g).(+r)` where `.` is Haskell function composition. This evaluates `(+r)` and then `(+g)`. Here we omit the operand (a style of denoting a function called _point free_ in Haskell).
--
-- The commuting diagram below illustrates this generalisation. By commuting we understand that whatever the value chosen for the operand of `(+y)` the resulting value will be the same through either path of arrows in the diagram.
--
-- <img src="images/CDAnalysis26.png" width="400"/>

-- %% [markdown]
-- In functional programming terms we can read 2+3=5 in this way:
--
-- - (2+) is a _section_ of a function (specifically, a partially applied binary operator)
-- - 3 is the argument or operand
-- - 5 is the result or value
--
-- This shows that this concept of a function encapsulates all three ideas: operator, operand and value.  Consolidation like this is sometimes called a threshold concept in a DCG. That is, a core idea that can be difficult to grasp, but once comprehended allows the learner to see connections previously unseen.

-- %% [markdown]
-- A function machine is the usual way in primary schools to visualise the flow of operations in evaluating an equation. Use the drawing convention in this link to the [BBC bitesize](https://www.bbc.co.uk/bitesize/articles/zsywg2p#z2syxg8) definition to show/imagine the flow of data if (2+) is the function, and 3 is the initial value, and where (+3) is the function and 2 is the initial value. (2+) feeds its operand to the right of the function (+), (+3) feeds it to the left.
--
-- We say that these function machines are _equivalent_ to one another as they represent two permitted interpretations of 2+3=5.
--
-- Try running the code cell below. Add some more expressions using sections to add x and y, where x and y are named numbers. That is `(x+)` is a section of a curried function with the first argument already supplied, waiting for the second. What are the two arguments or operands of +? what is the argument of (+x)? of (x+)?

-- %%
x = 2::Apple
(+3)x

-- %% [markdown]
-- # Chapter 3: A short course in modelling with Cuisenaire
--
-- ![](images/CuiDCG.png)
--
-- In this chapter we introduce a series of lesson plans which have been trialled over 20 years in classrooms from Key Stage 1 to 5. They build on the pedagogy and content of Gattegno's text-book series Mathematics with Numbers in Colour. Coloured Cuisenaire rods have an established place in early arithmetic. The text book series shows how guided questionning can be used to visualise algebraic relationships through rod constructions and mathematical writing.
--
-- ## Lesson 1: Rods Primer
--
-- We can start with very simple observations about the Cuisenaire rods that follow from free play with the box of rods, and exercises chosen by the teacher taken from the first four chapters of Book 1 which is available to borrow from the internet archive. An online environment for exploring the rods is [here](https://nrich.maths.org/4348).
--
-- Students will understand:
-- * The five **properties** of rods. Students will make many comments but write any of these on the white board when said. Steer students towards the missing ones.
--   * Rods of the same colour have the same length
--   * Rods of the same length have the same colour
--   * Rods of different colours have different lengths
--   * Rods of different lengths have different colours
--   * A train of any length can be made with just the whites
-- * How to represent rods using algebraic notation (Gattegno's code letters are 'w','r','g','p','y','d' (dark green),'b' (black), 't' (tan),'B' (Blue), 'o' )
-- * How to perform basic operations using rods (juxstaposition end to end as a model for 'plus' or side by side as a model for 'difference').
--
-- These key insights are illustrated in the pictures that follow. They show
--
-- 1. At the outset in Year 1 we introduce all four arithmetic operations and unit fractions as operators with colour code letters for the rods (image taken from Gattegno Mathematics Book 1)
--    ![](images/duality.png)
--
-- 2. Rods can have different number names depending which rod they are measured with. Numbers can be whole or fractional magnitudes (Integers or Rationals).
--    In the figure taken in Year 3 the rods are measured with a Yellow.
--    ![](images/fractionalnames.png)

-- %% [markdown]
-- ## Lesson 2: Building Rods Data
--
-- The following technical vocabulary is introduced: Namespace, property, object, action, Colour, Rod, Train, type, sum type, function, deriving, Show, Print, Eq, Ord, Enum

-- %% [markdown]
-- <img src="images/s2023901IaBe053117DCGHaskell.png" width="400"/>
--
--
-- Some of these terms are part of a network of conceptual dependencies called *type classes* of Haskell's Standard Class Library -- part of which is shown in the figure.
--
--
-- Let's try and make our own `Colour` data type which matches what we know about rods.

-- %% [markdown]
-- To model the Rod domain as a `data type` we ask three questions
-- - what is the data?
-- - what is its structure?
-- - what are its properties?
--
-- ## What is the data?
--
-- If we just consider the collection of rods without the constructions (such as __trains__ formed by actions such as appending them end to end) then the `data` are the names that we choose for each rod.
--
-- Each choice of family of names is called a *namespace*. A rod may for example have a colour name (which is not unique, all rods of the same colour have the same name), a colour code letter, a whole number label which may represent its length as a multiple of the length of a chosen unit or a fractional operator which when applied to the unit of measure evaluates to its length.
--
-- Measuring with the smallest white cube is often taken as the unit of measurement. This will produce whole number names.
--
-- But as we have seen other rods may also serve as a unit. For example the white rod might be called '1/4' when measured with a purple. This is the `Rational` number `1 % 4` in Haskell.

-- %% [markdown]
-- ## What is the structure?
--
-- To model the *structure* we consider the kind of relationship possible between two arbitrary rods: they may be the same length or different lengths. This relationship is technically known as a __partial order__. We will need a way of checking if two rods are the same length, or different lengths.
--
-- The namespace is defined as the `Colour` data type. This consists of 10 different names, or `constructors`, listed in order, one for eacolour/length value measured with a White.
--
-- We also `derive` from some type classes which gives our rods some special abilities! What abilities are these?
--
-- * Implementing the `Show` derived class permits us to print something of the type `Colour`. This is useful for debugging!
-- * Implementing `Eq` allows us to compare two instances of a `Colour` to see if they are the same with the `==` predicate (a *predicate* is a function that returns a `Bool` value (`True` or `False`))
-- * `Ord` makes our data ordered! `Red < Yellow`, `Purple > Black`, `Yellow <= Yellow`. To implement `Ord`, you **must** implement `Eq`!
-- * `Enum` makes our type enumerable! `Red` is the successor or `White`, `Purple` is the successor of `Green` and so on!

-- %%
-- First of all, we model the properties of the rods with their Gattegno Colour 
-- names as a "sum" type deriving the classes Show, Eq, Ord and Enum
data Colour = White 
            | Red 
            | Green 
            | Purple 
            | Yellow 
            | DarkGreen 
            | Black 
            | Brown 
            | Blue 
            | Orange 
            deriving (Show,Eq, Ord, Enum)

-- %%
-- test this out by running the following
print Red
White == Red
White == White
Red <= Green
Red <= Red
3+3
succ 3 -- successor value of 3
succ White --successor value of White

-- %% [markdown]
-- The `succ` function is available to us since we have derived `Colour` from the `Enum` type class.

-- %% [markdown]
-- ## Lesson 3: Defining simple functions
--
-- Functions are defined in a series of equations. Each one sets out (on the left of the equals sign) that the equational definition is applied when the input Colour argument value matches its specified value to realise the value on the right.
--
-- A function definition may start with an optional `type signature`. This is one or more type names (or type variables) giving the type of the input argument(s) and return value, listed between `->`.
--
-- Complete the following function $code(x) \mapsto y$ to map each Gattegno colour name $x :: \texttt{Colour}$ to its corresponding $y :: \texttt{Char}$
--
-- That is mathematically speaking:
--
-- $code(\texttt{White}) \mapsto \texttt{`w'}$
-- $code(\texttt{Red}) \mapsto \texttt{`r'}$
-- $\dots$

-- %%
code :: Colour -> Char
code White = 'w'
code Red = 'r'
-- TODO fill in the rest!

-- %% [markdown]
-- Play around with your `code` function below:

-- %%
code White

-- %% [markdown]
-- It can be exhausting writing every permutation! So Haskell functions also take a lowercase argument which accepts "any" value.
--
-- Here we have written a function that accepts any colour value, and converts it to its rod length. The variable colour matches any valid Colour constructor.
--
-- We use the function `fromEnum` to convert the value of the variable from a name to a number. `fromEnum colour` is an enumeration value in the range 0 to 9 assigned to the colour by deriving from `Enum`! We need to add `1` to `(fromEnum colour)` to make the length measured with a White.

-- %%
rodLength:: Colour -> Int
rodLength colour = 1 + fromEnum colour

-- %% [markdown]
-- Try it out below!

-- %%
rodLength DarkGreen

-- %% [markdown]
-- ## Lesson 4: Interrogating types
-- We can interrogate the system to find the type of a variable (or the type signature of a function) with the command `:t` or `:type`

-- %%
-- try these
:type White
:type 3
:type code
:type (==)

-- %%
(==) White Red
:type (==) White Red

-- %% [markdown]
-- Note that binary operators defined with symbols can be called in two ways.
--
-- Normally, (appearing between two inputs):

-- %%
White == Red
White > Red

-- %% [markdown]
-- Or like a named function (appearing before both inputs) by wrapping the function symbol in parentheses

-- %%
(==) White Red
(>) White Red

-- %% [markdown]
-- What do you expect type of `(==) White` to be? Try running it, does it conform to your expectations?

-- %%
:type (==) White

-- %% [markdown]
-- We call `(==) White` a pointfree function. It is a function definition without its input argument being specified. Try this

-- %%
myWhiteTest = (==) White
myWhiteTest Red
myWhiteTest White

-- %% [markdown]
-- ## Lesson 5: Lists
--
-- We can define a train of rods as a list of rods. Lists are written like so:

-- %%
[Red, Green, Blue]
:type [Red, Green, Blue]

-- %% [markdown]
-- We can name a list of Colour with a `type synonym`: Type Train = [Colour]

-- %%
type Train = [Colour]
train1 = [Red,Green,Blue] :: Train
:t train1

-- %% [markdown]
-- Thanks to deriving `Enum` we can use the `[a .. b]` syntax to generate a list containing `a`, `b`, and all the values in-between!

-- %%
[1..10]

-- %%
 [White .. Orange]

-- %% [markdown]
-- Using generator syntax (`x <- xs`), we can build lists from other lists, transforming the values of the original list. This is called a *list comprehension*. It has a similar syntax to a set generator in mathematics.

-- %%
[i * 10 | i <- [1..10]]

-- %%
[rodLength c | c <- [White .. Orange]]

-- %%
[i | i <- [1..10], even i]

-- %% [markdown]
-- Can you generate a list of all odd rod lengths, generated from the list `[White..Blue]`? What do you think the type signatures for *even* and *odd* might be?

-- %%
:t even
:t odd

-- %%
[White .. Blue] -- edit this to generate all odd rod lengths.

-- %% [markdown]
-- ## Lesson 6: Sums
--
-- Let's take a look at some handy functions to deal with numbers!

-- %% [markdown]
-- `sum` is a very handy method which adds together all integers in a list. What do you think its type signature might be?

-- %%
:type sum
sum [1..10]

-- %% [markdown]
-- We are now primed to write a method to sum the lengths in a train of rods.

-- %%
rodSum :: [Colour] -> Int
rodSum colours = sum [rodLength c | c <- colours ]

-- %%
rodSum [White, White, Red]

-- %% [markdown]
-- We can then test to see if the sum of a train of rods sums to a given rod

-- %%
sameLength :: [Colour] -> [Colour] -> Bool
sameLength colours1 colours2 = rodSum colours1 == rodSum colours2

-- %%
sameLength [White, White] [Red]

-- %% [markdown]
-- ## Lesson 7: More generators.
--
-- Lists can be generated from more than one inner list, like so.

-- %%
[[i, j] | i <- [1..3], j <- [1..3]]

-- %% [markdown]
-- Here we have introduced a list of lists! Each list containing 2 elements covering all values.

-- %%
[[c1, c2] |c1 <- [Purple .. DarkGreen], c2 <- [Red .. Green]]

-- %% [markdown]
-- We can combine this with our usual set of rules:

-- %%
[rodSum [c1, c2] | c1 <- [White .. Black], c2 <- [White .. Black]]

-- %% [markdown]
-- As a final challenge are you able to:
--
-- 1. Generate a list of rodSums from a train of **two** elements.
-- 1. Calculate this for all possible 2-colour trains, `[White, White]`, `[White, Red]`, ..., `[Orange, Orange]`.
-- 1. Can you filter the list such that it excludes all trains where the two elements are the same? `[White, White]`, `[Red, Red]`, etc.. (Hint: `(/=)` is the opposite of `(==)`)
-- 1. Generate a list of 2-rod trains equivalent in length to a given rod.

-- %%
[ [c1] ++ [c2] | c1 <- [White .. Black], c2 <- [White .. Black], sameLength (c1:[c2]) [Green]]

-- %%
:type sum

-- %% [markdown]
-- ## Lesson 8: Modeling $\mathbb{Z}/(10\mathbb{Z})$
--
-- By changing the `Colour` data type declaration and making a custom instance of `Enum` we can redefine the `succ` and `pred` functions to wrap around. This makes the colour staircase a __referent model__ for the integers modulo 10. As we are making it a custom instance we need to remove `Enum` from the `deriving (..)` list.
--
-- We can group the data declaration and its functions (structure) in a module, and export the data declaration and the function names with the code
--
--
-- ```
-- {-# LANGUAGE DeriveAnyClass #-}
-- {-# LANGUAGE DeriveGeneric  #-}
--
-- module Colour
--   ( Colour(..)
--   , enumCount
--   , modCol
--   , toEnumMaybe
--   ) where
-- ```
--
-- We have created a new cell with the remaining code below. `maxBound` is instantiated by deriving from the `Bounded` typeclass. It is the largest (greatest) value that `Colour` can represent.
--
-- By making `Colour` an instance of type class `Num` we can use the functions (+) etc with Colours.
--
-- Test this with `Red + White` and `toEnum 100::Colour` and `toEnumMaybe 100::Maybe Colour` (say).

-- %%
data Colour
  = Orange | White | Red | Green | Purple
  | Yellow | DarkGreen | Black | Brown | Blue
  deriving (Show, Eq, Ord, Bounded)

-- Total, reusable count of constructors
enumCount :: Int
enumCount = fromEnum (maxBound :: Colour) + 1

-- Wrap an Int into the Colour range (handles negatives correctly)
modCol :: Int -> Colour
modCol i = toEnum (i `mod` enumCount)

-- A safe alternative to toEnum
toEnumMaybe :: Int -> Maybe Colour
toEnumMaybe n
  | 0 <= n && n < enumCount = Just (toEnum n)
  | otherwise              = Nothing

instance Enum Colour where
  -- If you keep the constructor order as the intended order,
  -- you can define Enum via an explicit list to avoid big case trees.
  fromEnum c = case c of
    Orange    -> 0
    White     -> 1
    Red       -> 2
    Green     -> 3
    Purple    -> 4
    Yellow    -> 5
    DarkGreen -> 6
    Black     -> 7
    Brown     -> 8
    Blue      -> 9

  -- Make toEnum total by wrapping (instead of throwing an error)
  toEnum n = case n `mod` enumCount of
    0 -> Orange
    1 -> White
    2 -> Red
    3 -> Green
    4 -> Purple
    5 -> Yellow
    6 -> DarkGreen
    7 -> Black
    8 -> Brown
    _ -> Blue

  succ c = modCol (fromEnum c + 1)
  pred c = modCol (fromEnum c - 1)

instance Num Colour where
  (+) a b   = modCol (fromEnum a + fromEnum b)
  (*) a b   = modCol (fromEnum a * fromEnum b)
  negate    = modCol . negate . fromEnum
  abs       = modCol . abs    . fromEnum
  signum    = modCol . signum . fromEnum
  fromInteger = modCol . fromInteger

-- %% [markdown]
-- An even simpler version of the code, that uses the declared constructor order as the `Enum` order and avoids the big case tree is:

-- %%
data Colour = Orange | White | Red | Green | Purple
            | Yellow | DarkGreen | Black | Brown | Blue
            deriving (Show, Eq, Ord, Bounded, Enum)

enumCount :: Int
enumCount = fromEnum (maxBound :: Colour) + 1

modCol :: Int -> Colour
modCol i = toEnum (i `mod` enumCount)

instance Num Colour where
  (+) a b   = modCol (fromEnum a + fromEnum b)
  (*) a b   = modCol (fromEnum a * fromEnum b)
  negate    = modCol . negate . fromEnum
  abs       = modCol . abs    . fromEnum
  signum    = modCol . signum . fromEnum
  fromInteger = modCol . fromInteger

-- %% [markdown]
-- # Afterword
--
-- In Gattegno's The Computer and the Mind (1981) he addresses the role of computer technology in educational process design. He suggests that fruitful comparison between computers and human faculties must be drawn with the mind rather than the brain; explores software as an objectification of certain mental operations; argues for an emerging universe of nothings -- minute energetic shifts that underwrite both cognition and computation; and derives practical, awareness-first consequences for pedagogy. His emphasis is on awareness, knowledge integration, and the computer as an amplifier of mental presence rather than as a repository of memory or a drill engine.
--
--
-- ## The dilemma: mind--brain
--
-- Gattegno opens by reframing the question that popularised comparison of computation and biology: not brain versus computer, but mind versus computer. The reason is methodological. The mind is uniquely self-referential: it is capable of knowing itself and of knowing its creations (language, tools, models, computers). Notwithstanding the tendency to anthropomorphise software neither brains nor computers---considered as tissues or circuits---possess this reflexive capacity (Machines That Mimic Thought, Ian Benson, New Scientist, 1971). The appropriate locus for a conversation about computers is thus the mind in dialogue with its own objectifications.
--
-- Gattegno extends the the classical partitions (Greek _soma--psyche--nous_ and the more common Roman _body--mind_ with a proposed hierarchy in which the self, as energy, remains at the peak; it objectifies (1) soma, through embryogenesis and integration of bodily systems; (2) psyche, as guardianship of automatisms that free attention for novelty; and (3) mind, as the locus of perception, action, feeling, and thought.
--
-- The brain's tissue is maintained by the psyche; its functionings are taught by the mind. Awareness is the catalytic key that lets mental acts observe, adjust, and transform themselves. The _mind--brain_ problem is thereby recast as a question about how self-energised awareness educates a biological substrate to sustain increasingly subtle, integrated, and transcendent operations.
--
-- ## Beyond programming: the universe of nothings
--
-- What lies beyond competence in coding is a transformation of mental presence. Computers react with negligible inertia and ruthless exactness to minuscule deviations; this trains alertness, precision, and a sustained now---a felt sense of several co-present projects, constraints, and levels of description actively cooperating. The practitioner experiences the mind's dynamics more acutely than in writing or painting because many dialogues (aim, logic, interface, feedback) synchronise in tight loops.
--
-- This experience invites a shift in ontology. The computer popularises attention to very small energetic differences---nothings---that make a difference: subthreshold changes that nevertheless steer the course of thinking and computing. By analogy, cognition operates through minute energetic organisations whose effects are spectacular when well-integrated (as molecules do relative to atoms). Mental acts move faster than light in their combinatorial reach because they are not spatial translations but reorganisations of relations---again, shifts among nothings.
--
-- Intuition, in this framework, is the mind's continuous synthesis that holds the whole while focusing on a detail, never losing contact with the total energetic field. The computer, precisely because it is unforgiving and nearly massless in response, becomes a laboratory for intuition: it rewards criteria that are crisp, compositional, and exactly sufficient; it punishes vagueness.
--
-- Thus an epistemology of creation emerges: vision, essential dynamics, and constraint-awareness generate criteria; criteria filter hypotheses; filtered hypotheses catalyse new insights; insights are objectified as programs or generative AI prompts; programs alter both machine use and human comprehension.

-- %% [markdown]
-- Sociality Mathematics CIC (2025), licence CC BY-NC-ND Attribution-NonCommercial-NoDerivs https://creativecommons.org/licenses/. BCME10 Notebook is a trademark of Sociality Mathematics CIC.
