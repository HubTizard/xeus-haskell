-- %% [markdown]
-- Properties of Number
-- - Proportion
-- - Percentages
-- - Fractions and Decimals
-- - Indices
-- - Standard form
-- - Algebra - Simplify, Expand, Factorise, Substitute

-- %% [markdown]
-- Proportion

-- %% [markdown]
-- I have 24 jaffa cakes and five grandchildren. One is too small to have one. I don't want anyone to have more than anyone else. How many do they each have?

-- %% [markdown]
-- $24 / 4 = 6$

-- %%
24 `div` 4
-- Out:
-- 6

-- %% [markdown]
-- Indices

-- %% [markdown]
-- $5^3 * 5^8 = 5^{11}$

-- %% [markdown]
-- Factorising

-- %% [markdown]
-- 84 = 2 * 42.
--
-- 42 = 2 *21.
--
-- 21 = 7*3

-- %% [markdown]
-- Percentages
--
-- 100% = 420
-- what is 125%?

-- %% [markdown]
-- 100 -> 420, 25 -> 105, 125 -> 525

-- %% [markdown]
-- Fractions

-- %% [markdown]
-- 6/5 to decimal

-- %% [markdown]
-- 1.2

-- %%
6 / 5 :: Double
-- Out:
-- 1.2

-- %% [markdown]
-- Standard Form

-- %% [markdown]
-- $(4*10^3) * (7*10^5)$

-- %% [markdown]
-- $4 * 7 = 28 -> 5 + 3 = 8 -> 28/10 = 2.8 -> 8+1 = 9 -> 2.8 * 10^9$

-- %% [markdown]
-- Algebra - Simplify, Expand, Factorise, Substitute

-- %% [markdown]
-- $8x^2 + 4x -> 4x (2x + 1)$

-- %% [markdown]
-- $3x^2 = 12 -> x = 2$
